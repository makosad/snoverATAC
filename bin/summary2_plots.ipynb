# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# summary_path = sys.argv[1]
summary_path = '/home/dmakosa/working_data_02/snoverATAC/final.summary2.csv'
# Read in the dependencies
summary = pd.read_csv(summary_path, sep = ',')

# %%
summary
# Out:
#                                       Sample ID           Genome  \
# 0        RL3210_01_dirty_THS_30_shortREV_lowTn5  GRCh38_and_mm10
# 1     RL3210_02_dirty_THS_30_shortREV_mediumTn5  GRCh38_and_mm10
# 2       RL3210_03_dirty_THS_30_shortREV_highTn5  GRCh38_and_mm10
# 3       RL3210_04_dirty_OMNI_30_shortREV_lowTn5  GRCh38_and_mm10
# 4    RL3210_05_dirty_OMNI_30_shortREV_mediumTn5  GRCh38_and_mm10
# ..                                          ...              ...
# 379     RL4632_92_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 380     RL4632_93_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 381     RL4632_94_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 382       RL4632_95_MIX_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 383      RL4632_96_Mouse_ctx_Homogen_TagBufferB  GRCh38_and_mm10
#
#           Pipeline version  Estimated number of cells (GRCh38)  \
# 0    cellranger-atac-2.0.0                                 641
# ...

# %%
summary = summary.loc[~summary['Sample ID'].str.contains('combined|bulk', case=False)]

# %%
summary
# Out:
#                                       Sample ID           Genome  \
# 0        RL3210_01_dirty_THS_30_shortREV_lowTn5  GRCh38_and_mm10
# 1     RL3210_02_dirty_THS_30_shortREV_mediumTn5  GRCh38_and_mm10
# 2       RL3210_03_dirty_THS_30_shortREV_highTn5  GRCh38_and_mm10
# 3       RL3210_04_dirty_OMNI_30_shortREV_lowTn5  GRCh38_and_mm10
# 4    RL3210_05_dirty_OMNI_30_shortREV_mediumTn5  GRCh38_and_mm10
# ..                                          ...              ...
# 379     RL4632_92_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 380     RL4632_93_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 381     RL4632_94_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 382       RL4632_95_MIX_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 383      RL4632_96_Mouse_ctx_Homogen_TagBufferB  GRCh38_and_mm10
#
#           Pipeline version  Estimated number of cells (GRCh38)  \
# 0    cellranger-atac-2.0.0                                 641
# ...

# %%
RL3210 = summary.loc[summary['Sample ID'].str.contains('RL3210', case=False)]
RL3294 = summary.loc[summary['Sample ID'].str.contains('RL3294', case=False)]
RL3295 = summary.loc[summary['Sample ID'].str.contains('RL3295', case=False)]
RL4632 = summary.loc[summary['Sample ID'].str.contains('RL4632', case=False)]

# %%
RL3210
# Out:
#                                          Sample ID           Genome  \
# 0           RL3210_01_dirty_THS_30_shortREV_lowTn5  GRCh38_and_mm10
# 1        RL3210_02_dirty_THS_30_shortREV_mediumTn5  GRCh38_and_mm10
# 2          RL3210_03_dirty_THS_30_shortREV_highTn5  GRCh38_and_mm10
# 3          RL3210_04_dirty_OMNI_30_shortREV_lowTn5  GRCh38_and_mm10
# 4       RL3210_05_dirty_OMNI_30_shortREV_mediumTn5  GRCh38_and_mm10
# ..                                             ...              ...
# 91   RL3210_92_sucrose_THS_37_blockedREV_mediumTn5  GRCh38_and_mm10
# 92     RL3210_93_sucrose_THS_37_blockedREV_highTn5  GRCh38_and_mm10
# 93     RL3210_94_sucrose_OMNI_37_blockedREV_lowTn5  GRCh38_and_mm10
# 94  RL3210_95_sucrose_OMNI_37_blockedREV_mediumTn5  GRCh38_and_mm10
# 95    RL3210_96_sucrose_OMNI_37_blockedREV_highTn5  GRCh38_and_mm10
#
#          Pipeline version  Estimated number of cells (GRCh38)  \
# 0   cellranger-atac-2.0.0                                 641
# ...

# %%
RL3294
# Out:
#                                           Sample ID           Genome  \
# 96           RL3294_01_dirty_THS_30_shortREV_lowTn5  GRCh38_and_mm10
# 97        RL3294_02_dirty_THS_30_shortREV_mediumTn5  GRCh38_and_mm10
# 98          RL3294_03_dirty_THS_30_shortREV_highTn5  GRCh38_and_mm10
# 99          RL3294_04_dirty_OMNI_30_shortREV_lowTn5  GRCh38_and_mm10
# 100      RL3294_05_dirty_OMNI_30_shortREV_mediumTn5  GRCh38_and_mm10
# ..                                              ...              ...
# 187   RL3294_92_sucrose_THS_37_blockedREV_mediumTn5  GRCh38_and_mm10
# 188     RL3294_93_sucrose_THS_37_blockedREV_highTn5  GRCh38_and_mm10
# 189     RL3294_94_sucrose_OMNI_37_blockedREV_lowTn5  GRCh38_and_mm10
# 190  RL3294_95_sucrose_OMNI_37_blockedREV_mediumTn5  GRCh38_and_mm10
# 191    RL3294_96_sucrose_OMNI_37_blockedREV_highTn5  GRCh38_and_mm10
#
#           Pipeline version  Estimated number of cells (GRCh38)  \
# 96   cellranger-atac-2.0.0                                 173
# ...

# %%
RL3295
# Out:
#                                           Sample ID           Genome  \
# 192          RL3295_01_dirty_THS_30_shortREV_lowTn5  GRCh38_and_mm10
# 193       RL3295_02_dirty_THS_30_shortREV_mediumTn5  GRCh38_and_mm10
# 194         RL3295_03_dirty_THS_30_shortREV_highTn5  GRCh38_and_mm10
# 195         RL3295_04_dirty_OMNI_30_shortREV_lowTn5  GRCh38_and_mm10
# 196      RL3295_05_dirty_OMNI_30_shortREV_mediumTn5  GRCh38_and_mm10
# ..                                              ...              ...
# 283   RL3295_92_sucrose_THS_37_blockedREV_mediumTn5  GRCh38_and_mm10
# 284     RL3295_93_sucrose_THS_37_blockedREV_highTn5  GRCh38_and_mm10
# 285     RL3295_94_sucrose_OMNI_37_blockedREV_lowTn5  GRCh38_and_mm10
# 286  RL3295_95_sucrose_OMNI_37_blockedREV_mediumTn5  GRCh38_and_mm10
# 287    RL3295_96_sucrose_OMNI_37_blockedREV_highTn5  GRCh38_and_mm10
#
#           Pipeline version  Estimated number of cells (GRCh38)  \
# 192  cellranger-atac-2.0.0                                 438
# ...

# %%
RL4632
# Out:
#                                    Sample ID           Genome  \
# 288        RL4632_01_Human_5580_10xLysis_THS  GRCh38_and_mm10
# 289        RL4632_02_Human_5580_10xLysis_THS  GRCh38_and_mm10
# 290        RL4632_03_Human_5580_10xLysis_THS  GRCh38_and_mm10
# 291        RL4632_04_Human_5580_10xLysis_THS  GRCh38_and_mm10
# 292          RL4632_05_MIX_5580_10xLysis_THS  GRCh38_and_mm10
# ..                                       ...              ...
# 379  RL4632_92_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 380  RL4632_93_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 381  RL4632_94_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 382    RL4632_95_MIX_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 383   RL4632_96_Mouse_ctx_Homogen_TagBufferB  GRCh38_and_mm10
#
#           Pipeline version  Estimated number of cells (GRCh38)  \
# 288  cellranger-atac-2.0.0                                 783
# 289  cellranger-atac-2.0.0                                 883
# ...

# %%
RL3210[['RL','well','cleanup','TagBuffer','TagTemp','MErev','Tn5conc']] = RL3210['Sample ID'].str.split("_", expand = True)
RL3294[['RL','well','cleanup','TagBuffer','TagTemp','MErev','Tn5conc']] = RL3294['Sample ID'].str.split("_", expand = True)
RL3295[['RL','well','cleanup','TagBuffer','TagTemp','MErev','Tn5conc']] = RL3295['Sample ID'].str.split("_", expand = True)
# Out:
# /home/dmakosa/working_data_01/apps/miniconda3/envs/snRNAseq/lib/python3.7/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
RL4632[['RL','well','Specie','SampleSource','LysisBuffer','TagBuffer']] = RL4632['Sample ID'].str.split("_", expand = True)

# %%
RL4632
# Out:
#                                    Sample ID           Genome  \
# 288        RL4632_01_Human_5580_10xLysis_THS  GRCh38_and_mm10
# 289        RL4632_02_Human_5580_10xLysis_THS  GRCh38_and_mm10
# 290        RL4632_03_Human_5580_10xLysis_THS  GRCh38_and_mm10
# 291        RL4632_04_Human_5580_10xLysis_THS  GRCh38_and_mm10
# 292          RL4632_05_MIX_5580_10xLysis_THS  GRCh38_and_mm10
# ..                                       ...              ...
# 379  RL4632_92_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 380  RL4632_93_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 381  RL4632_94_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 382    RL4632_95_MIX_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 383   RL4632_96_Mouse_ctx_Homogen_TagBufferB  GRCh38_and_mm10
#
#           Pipeline version  Estimated number of cells (GRCh38)  \
# 288  cellranger-atac-2.0.0                                 783
# 289  cellranger-atac-2.0.0                                 883
# ...

# %%
final = pd.concat([RL3210, RL3294, RL3295, RL4632], ignore_index=True, sort=False)

# %%
final
# Out:
#                                       Sample ID           Genome  \
# 0        RL3210_01_dirty_THS_30_shortREV_lowTn5  GRCh38_and_mm10
# 1     RL3210_02_dirty_THS_30_shortREV_mediumTn5  GRCh38_and_mm10
# 2       RL3210_03_dirty_THS_30_shortREV_highTn5  GRCh38_and_mm10
# 3       RL3210_04_dirty_OMNI_30_shortREV_lowTn5  GRCh38_and_mm10
# 4    RL3210_05_dirty_OMNI_30_shortREV_mediumTn5  GRCh38_and_mm10
# ..                                          ...              ...
# 379     RL4632_92_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 380     RL4632_93_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 381     RL4632_94_Human_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 382       RL4632_95_MIX_5609_Homogen_TagBufferB  GRCh38_and_mm10
# 383      RL4632_96_Mouse_ctx_Homogen_TagBufferB  GRCh38_and_mm10
#
#           Pipeline version  Estimated number of cells (GRCh38)  \
# 0    cellranger-atac-2.0.0                                 641
# ...

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Fraction of high-quality fragments in cells')
sns.stripplot(data = final, x = "RL", y = 'Fraction of high-quality fragments in cells', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3210, x = "Tn5conc", y = 'Fraction of high-quality fragments in cells')
sns.stripplot(data = RL3210, x = "Tn5conc", y = 'Fraction of high-quality fragments in cells', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3210, x = "TagBuffer", y = 'Fraction of high-quality fragments in cells')
sns.stripplot(data = RL3210, x = "TagBuffer", y = 'Fraction of high-quality fragments in cells', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3210, x = "cleanup", y = 'Fraction of high-quality fragments in cells')
sns.stripplot(data = RL3210, x = "cleanup", y = 'Fraction of high-quality fragments in cells', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Fraction of high-quality fragments in cells', hue = "TagBuffer")
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
RL3210
# Out:
#                                          Sample ID           Genome  \
# 0           RL3210_01_dirty_THS_30_shortREV_lowTn5  GRCh38_and_mm10
# 1        RL3210_02_dirty_THS_30_shortREV_mediumTn5  GRCh38_and_mm10
# 2          RL3210_03_dirty_THS_30_shortREV_highTn5  GRCh38_and_mm10
# 3          RL3210_04_dirty_OMNI_30_shortREV_lowTn5  GRCh38_and_mm10
# 4       RL3210_05_dirty_OMNI_30_shortREV_mediumTn5  GRCh38_and_mm10
# ..                                             ...              ...
# 91   RL3210_92_sucrose_THS_37_blockedREV_mediumTn5  GRCh38_and_mm10
# 92     RL3210_93_sucrose_THS_37_blockedREV_highTn5  GRCh38_and_mm10
# 93     RL3210_94_sucrose_OMNI_37_blockedREV_lowTn5  GRCh38_and_mm10
# 94  RL3210_95_sucrose_OMNI_37_blockedREV_mediumTn5  GRCh38_and_mm10
# 95    RL3210_96_sucrose_OMNI_37_blockedREV_highTn5  GRCh38_and_mm10
#
#          Pipeline version  Estimated number of cells (GRCh38)  \
# 0   cellranger-atac-2.0.0                                 641
# ...

# %%
RL3294
# Out:
#                                           Sample ID           Genome  \
# 96           RL3294_01_dirty_THS_30_shortREV_lowTn5  GRCh38_and_mm10
# 97        RL3294_02_dirty_THS_30_shortREV_mediumTn5  GRCh38_and_mm10
# 98          RL3294_03_dirty_THS_30_shortREV_highTn5  GRCh38_and_mm10
# 99          RL3294_04_dirty_OMNI_30_shortREV_lowTn5  GRCh38_and_mm10
# 100      RL3294_05_dirty_OMNI_30_shortREV_mediumTn5  GRCh38_and_mm10
# ..                                              ...              ...
# 187   RL3294_92_sucrose_THS_37_blockedREV_mediumTn5  GRCh38_and_mm10
# 188     RL3294_93_sucrose_THS_37_blockedREV_highTn5  GRCh38_and_mm10
# 189     RL3294_94_sucrose_OMNI_37_blockedREV_lowTn5  GRCh38_and_mm10
# 190  RL3294_95_sucrose_OMNI_37_blockedREV_mediumTn5  GRCh38_and_mm10
# 191    RL3294_96_sucrose_OMNI_37_blockedREV_highTn5  GRCh38_and_mm10
#
#           Pipeline version  Estimated number of cells (GRCh38)  \
# 96   cellranger-atac-2.0.0                                 173
# ...

# %%
RL3295
# Out:
#                                           Sample ID           Genome  \
# 192          RL3295_01_dirty_THS_30_shortREV_lowTn5  GRCh38_and_mm10
# 193       RL3295_02_dirty_THS_30_shortREV_mediumTn5  GRCh38_and_mm10
# 194         RL3295_03_dirty_THS_30_shortREV_highTn5  GRCh38_and_mm10
# 195         RL3295_04_dirty_OMNI_30_shortREV_lowTn5  GRCh38_and_mm10
# 196      RL3295_05_dirty_OMNI_30_shortREV_mediumTn5  GRCh38_and_mm10
# ..                                              ...              ...
# 283   RL3295_92_sucrose_THS_37_blockedREV_mediumTn5  GRCh38_and_mm10
# 284     RL3295_93_sucrose_THS_37_blockedREV_highTn5  GRCh38_and_mm10
# 285     RL3295_94_sucrose_OMNI_37_blockedREV_lowTn5  GRCh38_and_mm10
# 286  RL3295_95_sucrose_OMNI_37_blockedREV_mediumTn5  GRCh38_and_mm10
# 287    RL3295_96_sucrose_OMNI_37_blockedREV_highTn5  GRCh38_and_mm10
#
#           Pipeline version  Estimated number of cells (GRCh38)  \
# 192  cellranger-atac-2.0.0                                 438
# ...

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3210, x = "Tn5conc", y = 'Fraction of high-quality fragments in cells', hue = "TagBuffer")
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3210, x = "TagBuffer", y = 'Fraction of high-quality fragments in cells', hue = 'cleanup')
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3294, x = "TagBuffer", y = 'Fraction of high-quality fragments in cells', hue = 'cleanup')
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3295, x = "TagBuffer", y = 'Fraction of high-quality fragments in cells', hue = 'cleanup')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3295, x = "TagBuffer", y = 'Fraction of high-quality fragments overlapping peaks (GRCh38)', hue = 'cleanup')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3295, x = "Tn5conc", y = 'Fraction of high-quality fragments overlapping peaks (GRCh38)', hue = 'cleanup')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3295, x = "TagTemp", y = 'Fraction of high-quality fragments overlapping peaks (GRCh38)', hue = 'cleanup')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL4632, x = "TagBuffer", y = 'Fraction of high-quality fragments in cells', hue = 'LysisBuffer')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Observed multiplet rate')
sns.stripplot(data = final, x = "RL", y = 'Observed multiplet rate', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3295, x = "Tn5conc", y = 'Observed multiplet rate')
sns.stripplot(data = RL3295, x = "Tn5conc", y = 'Observed multiplet rate', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3295, x = "cleanup", y = 'Observed multiplet rate')
sns.stripplot(data = RL3295, x = "cleanup", y = 'Observed multiplet rate', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3295, x = "TagBuffer", y = 'Observed multiplet rate')
sns.stripplot(data = RL3295, x = "TagBuffer", y = 'Observed multiplet rate', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Observed multiplet rate', hue = "TagBuffer")
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Percent duplicates')
sns.stripplot(data = final, x = "RL", y = 'Percent duplicates', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Percent duplicates', hue = "TagBuffer")
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Fraction of high-quality fragments overlapping TSS (GRCh38)')
sns.stripplot(data = final, x = "RL", y = 'Fraction of high-quality fragments overlapping TSS (GRCh38)', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Fraction of high-quality fragments overlapping TSS (GRCh38)', hue = 'cleanup')
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Fraction of high-quality fragments overlapping TSS (mm10)')
sns.stripplot(data = final, x = "RL", y = 'Fraction of high-quality fragments overlapping TSS (mm10)', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3295, x = "Tn5conc", y = 'Fraction of high-quality fragments overlapping TSS (mm10)', hue = 'TagBuffer')
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL3295, x = "TagBuffer", y = 'Fraction of high-quality fragments overlapping TSS (mm10)', hue = 'TagTemp')
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL4632, x = "TagBuffer", y = 'Fraction of high-quality fragments overlapping TSS (mm10)', hue = "Specie")
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = RL4632, x = "TagBuffer", y = 'Fraction of high-quality fragments overlapping TSS (GRCh38)', hue = "Specie")
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Fraction of high-quality fragments overlapping peaks (GRCh38)')
sns.stripplot(data = final, x = "RL", y = 'Fraction of high-quality fragments overlapping peaks (GRCh38)', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Fraction of high-quality fragments overlapping peaks (GRCh38)', hue = 'cleanup')
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Fraction of high-quality fragments overlapping peaks (GRCh38)')
sns.stripplot(data = final, x = "RL", y = 'Fraction of high-quality fragments overlapping peaks (GRCh38)', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Fraction of high-quality fragments overlapping peaks (mm10)')
sns.stripplot(data = final, x = "RL", y = 'Fraction of high-quality fragments overlapping peaks (mm10)', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'TSS enrichment score')
sns.stripplot(data = final, x = "RL", y = 'TSS enrichment score', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'TSS enrichment score')
sns.stripplot(data = final, x = "RL", y = 'TSS enrichment score', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.ylim(0,20)
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Fragments in nucleosome-free regions')
sns.stripplot(data = final, x = "RL", y = 'Fragments in nucleosome-free regions', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()

# %%
sns.set_style("ticks")
sns.boxplot(data = final, x = "RL", y = 'Fragments flanking a single nucleosome')
sns.stripplot(data = final, x = "RL", y = 'Fragments flanking a single nucleosome', size=4, color=".3", linewidth=0)
plt.xticks(rotation=60, horizontalalignment='right')
plt.tight_layout()
